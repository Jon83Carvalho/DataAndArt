# %%
import pandas as pd

# %%
stock_df=pd.read_csv('day1.csv')

# %%
stock_df
# Out:
#                                timestamp exchange      price  size  \
# 0       2022-02-24 10:39:28.011500+00:00        K   1.392758   188
# 1       2022-02-24 10:39:28.011500+00:00        K   1.392758    54
# 2       2022-02-24 10:39:28.011500+00:00        K   0.278552    58
# 3       2022-02-24 11:06:25.620900+00:00        K   1.392758    12
# 4       2022-02-24 11:06:25.620900+00:00        K   0.000000     8
# ...                                  ...      ...        ...   ...
# 110355  2022-02-24 16:19:52.032900+00:00        T  79.186992    14
# 110356  2022-02-24 16:19:52.044600+00:00        T  79.186992     2
# 110357  2022-02-24 16:19:52.044600+00:00        T  79.186992     2
# 110358  2022-02-24 16:19:52.044600+00:00        V  79.349593    25
# 110359  2022-02-24 16:20:00.892700+00:00        D  79.169935    41
#
#                   conditions              id tape Symbol
# 0            [' ', 'F', 'T']  52983525030714    A   GRMN
# ...

# %%
stock_df_g=stock_df.groupby(['Symbol','price','size']).count()

# %%
stock_df_g
# Out:
#                         timestamp  exchange  conditions  id  tape
# Symbol price      size
# ASH    0.000000   100           2         2           2   2     2
#        0.151286   2             2         2           2   2     2
#                   100           4         4           4   4     4
#                   200           2         2           2   2     2
#        0.453858   28            2         2           2   2     2
# ...                           ...       ...         ...  ..   ...
# ZM     94.938272  1             2         2           2   2     2
#                   18            1         1           1   1     1
#        95.061728  5             1         1           1   1     1
#        95.555556  1             2         2           2   2     2
#        100.000000 1             1         1           1   1     1
#
# [52003 rows x 5 columns]

# %%
stock_df_g[['timestamp']].sort_values(by=['timestamp'])
# Out:
#                         timestamp
# Symbol price      size
# ZM     100.000000 1             1
# GL     51.234528  1             1
#        51.221498  1             1
#        51.198697  2             1
#        51.172638  3             1
# ...                           ...
# LDOS   63.380282  100          88
#        56.338028  100         108
#        61.032864  100         110
# GRMN   46.796657  1           138
# ZM     31.481481  1           164
#
# [52003 rows x 1 columns]

# %%
stock_df_g.to_csv('day1_g.csv')

# %% [markdown]
# ##Day2

# %%
stock_df=pd.read_csv('day2.csv')

# %%
stock_df
# Out:
#                                    timestamp exchange      price  size  \
# 0           2022-02-24 10:39:28.011500+00:00        K   1.392758   188
# 1           2022-02-24 10:39:28.011500+00:00        K   1.392758    54
# 2           2022-02-24 10:39:28.011500+00:00        K   0.278552    58
# 3           2022-02-24 11:06:25.620900+00:00        K   1.392758    12
# 4           2022-02-24 11:06:25.620900+00:00        K   0.000000     8
# ...                                      ...      ...        ...   ...
# 1126813     2022-03-01 20:49:22.708993+00:00        K  91.666667     5
# 1126814     2022-03-01 20:57:53.454466+00:00        K  83.333333     5
# 1126815  2022-03-01 20:59:43.073775795+00:00        Q  83.333333     5
# 1126816  2022-03-01 20:59:52.211307154+00:00        Q  83.333333     5
# 1126817  2022-03-01 21:00:01.704252180+00:00        Q  83.333333     5
#
#                    conditions              id tape Symbol
# ...

# %%
stock_df_g=stock_df.groupby(['Symbol','price','size']).count()

# %%
stock_df_g
# Out:
#                         timestamp  exchange  conditions  id  tape
# Symbol price      size
# ABNB   0.000000   45            1         1           1   1     1
#        0.138696   1             1         1           1   1     1
#        0.277393   1             1         1           1   1     1
#        0.693481   4             1         1           1   1     1
#                   22            3         3           3   3     3
# ...                           ...       ...         ...  ..   ...
# ZM     99.513973  63            2         2           2   2     2
#                   100           6         6           6   6     6
#        99.634265  16            2         2           2   2     2
#        100.000000 1             2         2           2   2     2
#                   100           2         2           2   2     2
#
# [462751 rows x 5 columns]

# %%
stock_df_g[['timestamp']].sort_values(by=['timestamp'])
# Out:
#                         timestamp
# Symbol price      size
# ZM     100.000000 1             1
# GL     51.234528  1             1
#        51.221498  1             1
#        51.198697  2             1
#        51.172638  3             1
# ...                           ...
# LDOS   63.380282  100          88
#        56.338028  100         108
#        61.032864  100         110
# GRMN   46.796657  1           138
# ZM     31.481481  1           164
#
# [52003 rows x 1 columns]

# %%
stock_df_g.to_csv('day2_g.csv')
